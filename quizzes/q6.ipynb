# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#q1
x = np.array([1, 2, 3])
y = np.array([2, 1, 3])
plt.plot(x, y, 'o:g')
plt.xlim(0, 4)
plt.ylim(0, 4)
# Out:
# (0.0, 4.0)

# %%
#q2
x = np.array([1, 2, 3])
y = np.array([2, 1, 3])
plt.plot(x, y, '+-.r')
plt.xlim(0, 4)
plt.ylim(0, 4)
# Out:
# (0.0, 4.0)

# %%
#q3
df = pd.read_csv('http://www.stat.wisc.edu/~jgillett/451/data/mtcars.csv', index_col=0)
plt.boxplot(df["mpg"], vert=False, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ba5392480>,
#   <matplotlib.lines.Line2D at 0x21ba4b297c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21ba4b29ac0>,
#   <matplotlib.lines.Line2D at 0x21ba4b29d60>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x21ba53bc8f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ba4b2a030>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ba4b2a330>],
#  'means': []}

# %%
#q4
cyl_counts = df["cyl"].value_counts()

bar_heights = cyl_counts.values
bar_labels = cyl_counts.index

plt.bar(bar_labels, bar_heights, color='skyblue')
# Out:
# <BarContainer object of 3 artists>

# %%
#q5
edges = [10, 15, 20, 25, 30, 35]
n, bins, patches = plt.hist(df["mpg"], bins=edges, edgecolor='black', alpha=0.7)

# %%
#q6
fig = plt.figure() # create new blank figure
fig.suptitle('gridspec: three plots using 1/4, 1/4, and 1/2 of figure')
gs = fig.add_gridspec(nrows=4, ncols=1) # grid of plot axes
x = np.linspace(start=0, stop=4*np.pi, num=100) # fake data
xlim = (0, 13) # common x-axis limits
ax1 = fig.add_subplot(gs[0, 0]) # first plot in top 1/4
ax1.plot(x, -2 + x/3, label=r'$y = -2 + \frac{x}{3}$')
ax1.set(xlim=xlim, ylim=(-2, 2))
ax1.xaxis.set_ticks([]) # suppress axis ticks & numbers
ax1.legend()
ax2 = fig.add_subplot(gs[1, 0]) # second plot in second 1/4
ax2.plot(x, np.cos(x), label=r'$y = \cos(x)$')
ax2.set(xlim=xlim, ylim=(-2, 2))
ax2.xaxis.set_ticks([]) # suppress axis ticks & numbers
ax2.legend()
ax3 = fig.add_subplot(gs[2:4, 0]) # third plot in bottom 1/2
ax3.plot(x, (-2 + x/3) + np.cos(x),
label=r'$y=\left(-2 + \frac{x}{3}\right) + \cos(x)$')
ax3.set(xlim=xlim, ylim=(-2, 6))
ax3.legend()

# %%
#q7
df.boxplot(column='mpg', by='gear', grid=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
# Out:
# <Axes: title={'center': 'mpg'}, xlabel='gear'>

# %%
#q8
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='mpg', hue='gear', fill=True, common_norm=False, alpha=0.6)
# Out:
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
#q9
colors = {3: 'red', 4: 'blue', 5: 'green'}
gear_colors = df['gear'].map(colors)

plt.figure(figsize=(10, 6))
plt.scatter(df['wt'], df['mpg'], c=gear_colors, edgecolors='w', alpha=0.7, s=100)

# %%
#q10
